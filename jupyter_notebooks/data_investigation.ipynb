# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data\inputs\raw\BankChurners.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\selin\AppData\Local\Temp\ipykernel_20304\839870042.py:1: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_csv('../data\inputs\raw\BankChurners.csv')
# C:\Users\selin\AppData\Local\Temp\ipykernel_20304\839870042.py:1: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_csv('../data\inputs\raw\BankChurners.csv')
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv('../data\inputs\raw\BankChurners.csv')
#       2 df
#
# ...

# %%
df = pd.read_csv('../data/inputs/raw/BankChurners.csv')

# %%
df = pd.read_csv('data.csv')
df = pd.read_csv('data/inputs/raw/BankChurners.csv')
df = pd.read_csv('../data/inputs/raw/BankChurners.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv('data.csv')
#       2 df = pd.read_csv('data/inputs/raw/BankChurners.csv')
#       3 df = pd.read_csv('../data/inputs/raw/BankChurners.csv')
#
# ...

# %%
df = pd.read_csv('../data/inputs/raw/BankChurners.csv')
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
print(df.shape)
df = df.drop_duplicates()
print(df.shape)
# Out:
# (10127, 23)
# (10127, 23)

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
print(df.head())
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
# 3. Transform: Clean and Prepare the data
# Drop irrelevant columns
cols_to_drop = ['CLIENTNUM']
df = df.drop(columns=cols_to_drop)

# %%
df_clean = df.drop(columns=cols_to_drop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_clean = df.drop(columns=cols_to_drop)
#
# File c:\Users\selin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category', 'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2']

# %%
df.columns = df.columns.str.strip()

# %%
if 'CLIENTNUM' in df.columns:
    df_clean = df.drop(columns=['CLIENTNUM'])
else:
    df_clean = df.copy()  # or continue using the existing df
# Check for missing values

# %%
df_clean = df_clean.rename(columns={
    'Attrition_Flag': 'Churn_Status'
})

# %%
df_clean.columns = df_clean.columns.str.lower()

# %%
if 'churn_status' in df_clean.columns:
    df_clean['churn_status'] = df_clean['churn_status'].map({
        'Attrited Customer': 1,
        'Existing Customer': 0
    })

# %%
print("Missing values:")
print(df_clean.isnull().sum())
# Out:
# Missing values:
# churn_status                                                                                                                          0
# customer_age                                                                                                                          0
# gender                                                                                                                                0
# dependent_count                                                                                                                       0
# education_level                                                                                                                       0
# marital_status                                                                                                                        0
# income_category                                                                                                                       0
# ...

# %%
if 'credit_limit' in df_clean.columns:
    df_clean = df_clean[df_clean['credit_limit'] > 0]

# %%
cols_to_drop = [
    'CLIENTNUM',
    'naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_1',
    'naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_2'
]

df_clean = df.drop(columns=[col for col in cols_to_drop if col in df.columns])

# %%
print("Missing values:")
print(df_clean.isnull().sum())
# Out:
# Missing values:
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# Income_Category                                                                                                                       0
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category', 'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2']

# %%
print.head()
print(df_clean.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print.head()
#       2 print(df_clean.head())
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'head'

# %%
print head()
# Out:
#   Cell In[31], line 1
#     print head()
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print.head()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'head'

# %%
print.shape
print(df_clean.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print.shape
#       2 print(df_clean.shape)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'shape'

# %%
print(df_clean.head())
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
print(df_clean.shape)
# Out:
# (10127, 22)

# %%
df = pd.read_csv('../data_inputs/raw/BankChurners.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df = pd.read_csv('../data_inputs/raw/BankChurners.csv')
#
# File c:\Users\selin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv('..data\inputs\raw\BankChurners.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\selin\AppData\Local\Temp\ipykernel_20304\1284872814.py:1: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_csv('..data\inputs\raw\BankChurners.csv')
# C:\Users\selin\AppData\Local\Temp\ipykernel_20304\1284872814.py:1: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_csv('..data\inputs\raw\BankChurners.csv')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df = pd.read_csv('..data\inputs\raw\BankChurners.csv')
#       2 df
#
# ...

# %%
df = pd.read_csv('../data/inputs/raw/BankChurners.csv')
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.columns = df.columns.str.strip()

# %%
print("Original column count:", len(df.columns))
# Out:
# Original column count: 23

# %%
columns_to_drop = [
    'CLIENTNUM',
    'naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_1',
    'naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_2'
]

# %%
df_clean = df.drop(columns=[col for col in columns_to_drop if col in df.columns])

# %%
print("Cleaned column count:", len(df_clean.columns))
# Out:
# Cleaned column count: 22

# %%
print("Matching columns that exist:")
for col in columns_to_drop:
    if col in df.columns:
        print(f"✓ {col}")
    else:
        print(f"✗ {col} NOT FOUND")
# Out:
# Matching columns that exist:
# ✓ CLIENTNUM
# ✗ naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_1 NOT FOUND
# ✗ naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_2 NOT FOUND

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'CLIENTNUM'
# 'Attrition_Flag'
# 'Customer_Age'
# 'Gender'
# 'Dependent_count'
# 'Education_Level'
# 'Marital_Status'
# 'Income_Category'
# 'Card_Category'
# 'Months_on_book'
# 'Total_Relationship_Count'
# 'Months_Inactive_12_mon'
# 'Contacts_Count_12_mon'
# 'Credit_Limit'
# 'Total_Revolving_Bal'
# 'Avg_Open_To_Buy'
# 'Total_Amt_Chng_Q4_Q1'
# 'Total_Trans_Amt'
# 'Total_Trans_Ct'
# 'Total_Ct_Chng_Q4_Q1'
# 'Avg_Utilization_Ratio'
# 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1'
# 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'

# %%
columns_to_drop = [
    'CLIENTNUM',
    'naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_1',
    'naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_2'
]

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'CLIENTNUM'
# 'Attrition_Flag'
# 'Customer_Age'
# 'Gender'
# 'Dependent_count'
# 'Education_Level'
# 'Marital_Status'
# 'Income_Category'
# 'Card_Category'
# 'Months_on_book'
# 'Total_Relationship_Count'
# 'Months_Inactive_12_mon'
# 'Contacts_Count_12_mon'
# 'Credit_Limit'
# 'Total_Revolving_Bal'
# 'Avg_Open_To_Buy'
# 'Total_Amt_Chng_Q4_Q1'
# 'Total_Trans_Amt'
# 'Total_Trans_Ct'
# 'Total_Ct_Chng_Q4_Q1'
# 'Avg_Utilization_Ratio'
# 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1'
# 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'

# %%
print("Cleaned column count:", len(df_clean.columns))
# Out:
# Cleaned column count: 22

# %%
columns_to_drop = [
    'CLIENTNUM',
    'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
    'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'
]

# %%
df_clean = df.drop(columns=[col for col in columns_to_drop if col in df.columns])
print("Cleaned column count:", len(df_clean.columns))
# Out:
# Cleaned column count: 20

# %%
print("Cleaned column count:", len(df_clean.columns))
# Out:
# Cleaned column count: 20

# %%
df = df.rename(columns={'Attrition_Flag': 'Churn_Status'})

# %%
df['Churn_Status'] = df['Churn_Status'].map({
    'Attrited Customer': 1,
    'Existing Customer': 0
})

# %%
df.to_csv('outputs/cleaned_bank_churn.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df.to_csv('outputs/cleaned_bank_churn.csv', index=False)
#
# File c:\Users\selin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df.to_csv('outputs/cleaned_bank_churn.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df.to_csv('outputs/cleaned_bank_churn.csv', index=False)
#
# File c:\Users\selin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import os
os.makedirs('outputs', exist_ok=True)

# %%
df.to_csv('outputs/cleaned_bank_churn.csv', index=False)
print("✅ File saved successfully.")
# Out:
# ✅ File saved successfully.
